# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
test_x = np.random.randint(1, 1000, (1800))
test_y = np.random.randint(1, 1000, (1800))
test_c = ['g','r','b']

# %%
plt.scatter(test_x, test_y, c=test_c, marker=".")
plt.show()

# %%
test = np.empty([0, 3])
test = np.vstack((test, [2, 3, 4]))
print(test)
# Out:
# []
